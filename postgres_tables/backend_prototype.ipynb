# %%
import pandas as pd
import geopandas as geopd
import matplotlib.pyplot as plt

from shapely import wkt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
password_1 = "postgres"
password_2 = "postgres"
database_path = f"postgresql://{password_1}:{password_2}@localhost:5432/ETL_7"

# %%
engine = create_engine(database_path)
connection = engine.connect()

# %%
# Collect the names of tables within the database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['housing', 'ds_jobs', 'breweries', 'salary', 'state_boundary']

# %%
# Using the inspector to print the column names within the 'dow' table and its types
columns = inspector.get_columns('housing')
for column in columns:
    print(column["name"], column["type"])
# Out:
# state VARCHAR
# average_home_price NUMERIC

# %%
columns = inspector.get_columns('ds_jobs')
for column in columns:
    print(column["name"], column["type"])
# Out:
# job_title VARCHAR
# category VARCHAR
# company_name VARCHAR
# city VARCHAR
# state VARCHAR
# post_date VARCHAR
# job_type VARCHAR
# salary_offered VARCHAR
# job_board VARCHAR
# job_id INTEGER

# %%
# Using the inspector to print the column names within the 'dow' table and its types
columns = inspector.get_columns('breweries')
for column in columns:
    print(column["name"], column["type"])
# Out:
# name VARCHAR
# brewery_type VARCHAR
# city VARCHAR
# state VARCHAR
# postal_code VARCHAR
# longitude VARCHAR
# latitude VARCHAR
# website_url VARCHAR
# brew_id INTEGER

# %%
# Using the inspector to print the column names within the 'dow' table and its types
columns = inspector.get_columns('salary')
for column in columns:
    print(column["name"], column["type"])
# Out:
# state VARCHAR
# job_title VARCHAR
# hourly_wage_mean NUMERIC
# hourly_wage_median NUMERIC
# annual_wage_median NUMERIC
# salary_id INTEGER

# %%
# Using the inspector to print the column names within the 'dow' table and its types
columns = inspector.get_columns('state_boundary')
for column in columns:
    print(column["name"], column["type"])
# Out:
# state VARCHAR
# geometry VARCHAR

# %%
# Declare a Base using `automap_base()`
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)

# %% [markdown]
# <strong>Procedure:</strong>
#
# <ol>
#     <li>Create DataFrame for each table using pd.read_sql()</li>
#     <li>Create json for each DataFrame.</li>
# </ol>

# %%
housing = pd.read_sql("SELECT * FROM housing", connection)

# %%
display(housing)
# Out:
#    state  average_home_price
# 0     CA         567563.5833
# 1     TX         208699.6667
# 2     NY         271862.0833
# 3     FL         257649.0833
# 4     IL         210242.8333
# 5     PA         194551.4167
# 6     OH         150804.0000
# 7     MI         172127.1667
# 8     GA         203632.0833
# 9     NC         204960.7500
# 10    NJ         349843.6667
# 11    VA         285270.5000
# 12    WA         412988.0833
# 13    MA         434274.0000
# 14    IN         155086.9167
# 15    AZ         267167.6667
# 16    TN         184767.2500
# 17    MO         164080.5833
# 18    MD         323450.0833
# 19    WI         193552.5000
# 20    MN         261241.5000
# 21    CO         414845.3333
# 22    AL         142704.5000
# 23    SC         192229.3333
# 24    LA         170722.9167
# 25    KY         146302.3333
# 26    OR         365922.1667
# 27    OK         129732.2500
# 28    CT         275120.5833
# 29    IA         152071.5000
# 30    MS         125752.5000
# 31    AR         129892.2500
# 32    KS         153547.6667
# 33    UT         354395.4167
# 34    NV         319823.2500
# 35    NM         203118.7500
# 36    WV         108142.0000
# 37    NE         177362.4167
# 38    ID         282628.4167
# 39    HI         742220.8333
# 40    ME         238261.0000
# 41    NH         303511.5000
# 42    RI         307510.2500
# 43    MT         286108.3333
# 44    DE         262325.1667
# 45    SD         213213.8333
# 46    AK         299099.0000
# 47    ND         236859.0833
# 48    VT         261071.3333
# 49    DC         734414.9167
# 50    WY         248255.0833

# %%
housing_json = housing.to_json(orient = "records")

# %%
display(housing_json)
# Out:
# '[{"state":"CA","average_home_price":567563.5833000001},{"state":"TX","average_home_price":208699.6667},{"state":"NY","average_home_price":271862.0833},{"state":"FL","average_home_price":257649.0833},{"state":"IL","average_home_price":210242.8333},{"state":"PA","average_home_price":194551.4167},{"state":"OH","average_home_price":150804.0},{"state":"MI","average_home_price":172127.1667},{"state":"GA","average_home_price":203632.0833},{"state":"NC","average_home_price":204960.75},{"state":"NJ","average_home_price":349843.6667},{"state":"VA","average_home_price":285270.5},{"state":"WA","average_home_price":412988.0833},{"state":"MA","average_home_price":434274.0},{"state":"IN","average_home_price":155086.9167},{"state":"AZ","average_home_price":267167.6667},{"state":"TN","average_home_price":184767.25},{"state":"MO","average_home_price":164080.5833},{"state":"MD","average_home_price":323450.0833},{"state":"WI","average_home_price":193552.5},{"state":"MN","average_home_price":261241.5},{"state":"CO","average_home_price":414845.3333},{"state":"AL","average_home_price":142704.5},{"state":"SC","average_home_price":192229.3333},{"state":"LA","average_home_price":170722.9167},{"state":"KY","average_home_price":146302.3333},{"state":"OR","average_home_price":365922.1667},{"state":"OK","average_home_price":129732.25},{"state":"CT","average_home_price":275120.5833},{"state":"IA","average_home_price":152071.5},{"state":"MS","average_home_price":125752.5},{"state":"AR","average_home_price":129892.25},{"state":"KS","average_home_price":153547.6667},{"state":"UT","average_home_price":354395.4167},{"state":"NV","average_home_price":319823.25},{"state":"NM","average_home_price":203118.75},{"state":"WV","average_home_price":108142.0},{"state":"NE","average_home_price":177362.4167},{"state":"ID","average_home_price":282628.4167},{"state":"HI","average_home_price":742220.8333000001},{"state":"ME","average_home_price":238261.0},{"state":"NH","average_home_price":303511.5},{"state":"RI","average_home_price":307510.25},{"state":"MT","average_home_price":286108.3333},{"state":"DE","average_home_price":262325.1667},{"state":"SD","average_home_price":213213.8333},{"state":"AK","average_home_price":299099.0},{"state":"ND","average_home_price":236859.0833},{"state":"VT","average_home_price":261071.3333},{"state":"DC","average_home_price":734414.9166999999},{"state":"WY","average_home_price":248255.0833}]'

# %%
ds_jobs = pd.read_sql('SELECT * FROM ds_jobs', connection)

# %%
ds_jobs.drop(columns = ["salary_offered"], inplace = True)

# %%
display(ds_jobs)
# Out:
#            job_title                     category  \
# 0     Data Scientist           Accounting/Finance
# 1     Data Scientist                         NULL
# 2     Data Scientist                         NULL
# 3       Asscoiate DS           Accounting/Finance
# 4          Senior DS                      biotech
# ...              ...                          ...
# 9466       Senior DS                computer jobs
# 9467        Chief DS                computer jobs
# 9468  Data Scientist                computer jobs
# 9469  Data Scientist                computer jobs
# 9470  Data Scientist  Engineering-or-architecture
#
#                               company_name            city state   post_date  \
# 0                  Farmers Insurance Group  Woodland Hills    CA  2019-02-06
# 1                           Luxoft USA Inc      Middletown    NJ  2019-02-05
# 2     Cincinnati Bell Technology Solutions        New York    NY  2019-02-05
# 3                                BlackRock        New York    NY  2019-02-06
# 4                              CyberCoders       Charlotte    NC  2019-02-05
# ...                                    ...             ...   ...         ...
# 9466                           CyberCoders           Miami    FL  2019-09-30
# 9467                           CyberCoders    East Hanover    NJ  2019-09-30
# 9468                  Pioneer Data Systems         Peapack    NJ  2019-09-30
# 9469                       OSI Engineering   San Francisco    CA  2019-09-30
# 9470                            Albany, OR          Albany    OR  2019-10-01
#
#        job_type job_board  job_id
# 0     Undefined    indeed       1
# 1     Undefined      dice       2
# 2     Full Time      dice       3
# 3     Undefined    indeed       4
# 4     Full Time   monster       5
# ...         ...       ...     ...
# 9466  Undefined   monster    9467
# 9467  Undefined   monster    9468
# 9468  Undefined   monster    9469
# 9469  Full Time   monster    9470
# 9470  Undefined    indeed    9471
#
# [9471 rows x 9 columns]

# %%
ds_jobs_json = ds_jobs.to_json(orient = "records")

# %%
display(ds_jobs_json)
# Out:
# '[{"job_title":"Data Scientist","category":"Accounting\\/Finance","company_name":"Farmers Insurance Group","city":"Woodland Hills","state":"CA","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":1},{"job_title":"Data Scientist","category":"NULL","company_name":"Luxoft USA Inc","city":"Middletown","state":"NJ","post_date":"2019-02-05","job_type":"Undefined","job_board":"dice","job_id":2},{"job_title":"Data Scientist","category":"NULL","company_name":"Cincinnati Bell Technology Solutions","city":"New York","state":"NY","post_date":"2019-02-05","job_type":"Full Time","job_board":"dice","job_id":3},{"job_title":"Asscoiate DS","category":"Accounting\\/Finance","company_name":"BlackRock","city":"New York","state":"NY","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":4},{"job_title":"Senior DS","category":"biotech","company_name":"CyberCoders","city":"Charlotte","state":"NC","post_date":"2019-02-05","job_type":"Full Time","job_board":"monster","job_id":5},{"job_title":"VP DS","category":"Accounting\\/Finance","company_name":"JP Morgan Chase","city":"New York","state":"NY","post_date":"2019-02-05","job_type":"Undefined","job_board":"indeed","job_id":6},{"job_title":"Data Scientist","category":"Accounting\\/Finance","company_name":"Spotify","city":"New York","state":"NY","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":7},{"job_title":"Senior DS","category":"NULL","company_name":"Xoriant Corporation","city":"Santa Clara","state":"CA","post_date":"2019-02-06","job_type":"Contract","job_board":"dice","job_id":8},{"job_title":"Asscoiate DS","category":"Accounting\\/Finance","company_name":"BlackRock","city":"New York","state":"NY","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":9},{"job_title":"Data Scientist","category":"NULL","company_name":"Adroit Resources","city":"San Francisco","state":"CA","post_date":"2019-02-05","job_type":"Contract","job_board":"dice","job_id":10},{"job_title":"Data Scientist","category":"Computer\\/Internet","company_name":"Northrop Grumman","city":"Monterey","state":"CA","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":11},{"job_title":"Data Scientist","category":"NULL","company_name":"Envoy Consulting Group, Inc","city":"Reston","state":"VA","post_date":"2019-02-05","job_type":"Full Time","job_board":"dice","job_id":12},{"job_title":"Data Scientist","category":"Computer\\/Internet","company_name":"Noblis","city":"Reston","state":"VA","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":13},{"job_title":"Data Scientist","category":"Computer\\/Internet","company_name":"ARUP Laboratories","city":"Salt Lake City","state":"UT","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":14},{"job_title":"Data Scientist","category":"NULL","company_name":"Perspecta","city":"Washington","state":"DC","post_date":"2019-02-05","job_type":"Full Time","job_board":"dice","job_id":15},{"job_title":"Senior DS","category":"NULL","company_name":"Pyramid Consulting, Inc.","city":"Mclean","state":"VA","post_date":"2019-02-05","job_type":"Undefined","job_board":"dice","job_id":16},{"job_title":"Senior DS","category":"NULL","company_name":"Orpine.com","city":"Boston","state":"MA","post_date":"2019-02-05","job_type":"Contract","job_board":"dice","job_id":17},{"job_title":"Data Scientist","category":"NULL","company_name":"Apeiro Technologies","city":"Mclean","state":"VA","post_date":"2019-02-05","job_type":"Contract","job_board":"dice","job_id":18},{"job_title":"Data Scientist","category":"Computer\\/Internet","company_name":"Bank of America","city":"Seattle","state":"WA","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":19},{"job_title":"Data Scientist","category":"Computer\\/Internet","company_name":"Sallie Mae","city":"Newark","state":"DE","post_date":"2019-02-06","job_type":"Undefined","job_board":"indeed","job_id":20} ...

# %%
breweries = pd.read_sql('SELECT * FROM breweries', connection)
display(breweries)
# Out:
#                                                    name brewery_type  \
# 0                     49th State Brewing Co - Anchorage      brewpub
# 1                                 49th State Brewing Co        micro
# 2                                   Alaskan Brewing Co.     regional
# 3                                  Anchorage Brewing Co        micro
# 4                                        Arkose Brewery        micro
# ...                                                 ...          ...
# 2270                           Suds Brothers Brewing Co      brewpub
# 2271                          Ten Sleep Brewing Company        micro
# 2272                         Wind River Brewing Co - WY      brewpub
# 2273                         WYOld West Brewing Company      brewpub
# 2274  Wyoming Territory Brewing / Eric Bischoff Fami...     contract
#
#            city state postal_code     longitude     latitude  \
# 0     Anchorage    AK  99501-2104  -149.8958196   61.2197366
# 1         Healy    AK       99743   -149.017877    63.864759
# 2        Juneau    AK  99801-9540  -134.4918763  58.35681231
# 3     Anchorage    AK  99515-1901  -149.8893581   61.1385311
# 4        Palmer    AK  99645-6689   -149.103408    61.582157
# ...         ...   ...         ...           ...          ...
# 2270   Evanston    WY  82930-3443  -110.9660936  41.26798687
# 2271  Ten Sleep    WY       82442          NULL         NULL
# 2272   Pinedale    WY       82941          NULL         NULL
# 2273     Powell    WY  82435-2335  -108.7574813  44.75451993
# 2274       Cody    WY       82414          NULL         NULL
#
#                                  website_url  brew_id
# 0             http://www.49statebrewing.com/        1
# 1      https://www.49statebrewing.com/denali        2
# 2                 http://www.alaskanbeer.com        3
# 3     http://www.anchoragebrewingcompany.com        4
# 4               http://www.arkosebrewery.com        5
# ...                                      ...      ...
# 2270      http://www.sudsbrothersbrewery.com     2271
# 2271        http://www.tensleepbrewingco.com     2272
# 2272       http://www.windriverbrewingco.com     2273
# 2273                http://www.wyoldwest.com     2274
# 2274      http://www.buffalobillcodybeer.com     2275
#
# [2275 rows x 9 columns]

# %%
breweries_json = breweries.to_json(orient = "records")
display(breweries_json)
# Out:
# '[{"name":"49th State Brewing Co - Anchorage","brewery_type":"brewpub","city":"Anchorage","state":"AK","postal_code":"99501-2104","longitude":"-149.8958196","latitude":"61.2197366","website_url":"http:\\/\\/www.49statebrewing.com\\/","brew_id":1},{"name":"49th State Brewing Co","brewery_type":"micro","city":"Healy","state":"AK","postal_code":"99743","longitude":"-149.017877","latitude":"63.864759","website_url":"https:\\/\\/www.49statebrewing.com\\/denali","brew_id":2},{"name":"Alaskan Brewing Co.","brewery_type":"regional","city":"Juneau","state":"AK","postal_code":"99801-9540","longitude":"-134.4918763","latitude":"58.35681231","website_url":"http:\\/\\/www.alaskanbeer.com","brew_id":3},{"name":"Anchorage Brewing Co","brewery_type":"micro","city":"Anchorage","state":"AK","postal_code":"99515-1901","longitude":"-149.8893581","latitude":"61.1385311","website_url":"http:\\/\\/www.anchoragebrewingcompany.com","brew_id":4},{"name":"Arkose Brewery","brewery_type":"micro","city":"Palmer","state":"AK","postal_code":"99645-6689","longitude":"-149.103408","latitude":"61.582157","website_url":"http:\\/\\/www.arkosebrewery.com","brew_id":5},{"name":"Baleen Brewing Co.","brewery_type":"micro","city":"Ketchikan","state":"AK","postal_code":"99901","longitude":"-131.817681","latitude":"55.472907","website_url":"https:\\/\\/www.baleenbrewing.com","brew_id":6},{"name":"Baranof Island Brewing Co","brewery_type":"closed","city":"Sitka","state":"AK","postal_code":"99835-9759","longitude":"-135.309951","latitude":"57.049586","website_url":"http:\\/\\/www.baranofislandbrewing.com","brew_id":7},{"name":"Barnaby Brewing Company","brewery_type":"micro","city":"Juneau","state":"AK","postal_code":"99801","longitude":"-134.405962","latitude":"58.300314","website_url":"http:\\/\\/www.barnabybrew.com","brew_id":8},{"name":"Bawden Street Brewing Company","brewery_type":"micro","city":"Ketchikan","state":"AK","postal_code":"99901","longitude":"-131.644822","latitude":"55.34321","website_url":"https:\\/\\/www.facebook.com\\/bawdenstreetbrewing","brew_id":9},{"name":"Bearpaw River Brewing Co","brewery_type":"micro","city":"Wasilla","state":"AK","postal_code":"99654-7679","longitude":"-149.4127103","latitude":"61.5752695","website_url":"http:\\/\\/bearpawriverbrewing.com","brew_id":10},{"name":"Bleeding Heart Brewery","brewery_type":"closed","city":"Palmer","state":"AK","postal_code":"99645-6972","longitude":"-149.109799","latitude":"61.601303","website_url":"http:\\/\\/facebook.com\\/bleedingheartbrewery","brew_id":11},{"name":"Broken Tooth Brewing Co","brewery_type":"brewpub","city":"Anchorage","state":"AK","postal_code":"99501-1815","longitude":"-149.8437638","latitude":"61.2225517","website_url":"https:\\/\\/brokentoothbrewing.net","brew_id":12},{"name":"Cooper Landing Brewing Company","brewery_type":"micro","city":"Cooper Landing","state":"AK","postal_code":"99572","longitude":"-149.8478495","latitude":"60.4952185","website_url":"http:\\/\\/www.cooperlandingbrewing.com","brew_id":13},{"name":"Cynosure Brewing","brewery_type":"micro","city":"Anchorage","state":"AK","postal_code":"99518-1363","longitude":"-149.881789","latitude":"61.168841","website_url":"https:\\/\\/www.cynosure.beer","brew_id":14},{"name":"Denali Brewing Company","brewery_type":"micro","city":"Talkeetna","state":"AK","postal_code":"99676","longitude":"-150.029188","latitude":"62.161453","website_url":"http:\\/\\/www.denalibrewing.com","brew_id":15},{"name":"Devil\'s Club Brewing","brewery_type":"brewpub","city":"Juneau","state":"AK","postal_code":"99801-1223","longitude":"-134.406956","latitude":"58.301309","website_url":"http:\\/\\/www.devilsclubbrewing.com","brew_id":16},{"name":"Faults Brewing","brewery_type":"planning","city":"Anchorage","state":"AK","postal_code":"99509-0312","longitude":"-149.8948523","latitude":"61.2163129","website_url":"NULL","brew_id":17},{"name":"Forbidden Peak Brewery","brewery_type":"micro","city":"Juneau","state":"AK","postal_code":"99801","longitude":"-134. ...

# %%
salary = pd.read_sql('SELECT * FROM salary', connection)
display(salary)
# Out:
#    state                                          job_title  hourly_wage_mean  \
# 0     AL             Database Administrators and Architects             41.13
# 1     AK             Database Administrators and Architects             41.80
# 2     AK  Data Scientists and Mathematical Science Occup...             33.83
# 3     AZ             Database Administrators and Architects             48.58
# 4     AZ  Data Scientists and Mathematical Science Occup...             52.31
# ..   ...                                                ...               ...
# 84    WV             Database Administrators and Architects             34.27
# 85    WV  Data Scientists and Mathematical Science Occup...             33.39
# 86    WI             Database Administrators and Architects             42.64
# 87    WI  Data Scientists and Mathematical Science Occup...             41.20
# 88    WY             Database Administrators and Architects             28.06
#
#     hourly_wage_median  annual_wage_median  salary_id
# 0                39.00             81130.0          1
# 1                41.45             86210.0          2
# 2                33.10             68840.0          3
# 3                47.49             98780.0          4
# 4                54.54            113430.0          5
# ..                 ...                 ...        ...
# 84               31.64             65800.0         85
# 85               29.15             60630.0         86
# 86               42.32             88020.0         87
# 87               39.77             82710.0         88
# 88               25.48             53000.0         89
#
# [89 rows x 6 columns]

# %%
salary.replace("Database Administrators and Architects", "Data Engineer", inplace = True)
salary.replace("Data Scientists and Mathematical Science Occupations, All Other", "Data Scientist", inplace = True)
display(salary)
# Out:
#    state       job_title  hourly_wage_mean  hourly_wage_median  \
# 0     AL   Data Engineer             41.13               39.00
# 1     AK   Data Engineer             41.80               41.45
# 2     AK  Data Scientist             33.83               33.10
# 3     AZ   Data Engineer             48.58               47.49
# 4     AZ  Data Scientist             52.31               54.54
# ..   ...             ...               ...                 ...
# 84    WV   Data Engineer             34.27               31.64
# 85    WV  Data Scientist             33.39               29.15
# 86    WI   Data Engineer             42.64               42.32
# 87    WI  Data Scientist             41.20               39.77
# 88    WY   Data Engineer             28.06               25.48
#
#     annual_wage_median  salary_id
# 0              81130.0          1
# 1              86210.0          2
# 2              68840.0          3
# 3              98780.0          4
# 4             113430.0          5
# ..                 ...        ...
# 84             65800.0         85
# 85             60630.0         86
# 86             88020.0         87
# 87             82710.0         88
# 88             53000.0         89
#
# [89 rows x 6 columns]

# %%
salary_json = salary.to_json(orient = "records")
display(salary_json)
# Out:
# '[{"state":"AL","job_title":"Data Engineer","hourly_wage_mean":41.13,"hourly_wage_median":39.0,"annual_wage_median":81130.0,"salary_id":1},{"state":"AK","job_title":"Data Engineer","hourly_wage_mean":41.8,"hourly_wage_median":41.45,"annual_wage_median":86210.0,"salary_id":2},{"state":"AK","job_title":"Data Scientist","hourly_wage_mean":33.83,"hourly_wage_median":33.1,"annual_wage_median":68840.0,"salary_id":3},{"state":"AZ","job_title":"Data Engineer","hourly_wage_mean":48.58,"hourly_wage_median":47.49,"annual_wage_median":98780.0,"salary_id":4},{"state":"AZ","job_title":"Data Scientist","hourly_wage_mean":52.31,"hourly_wage_median":54.54,"annual_wage_median":113430.0,"salary_id":5},{"state":"AR","job_title":"Data Engineer","hourly_wage_mean":37.31,"hourly_wage_median":37.57,"annual_wage_median":78150.0,"salary_id":6},{"state":"CA","job_title":"Data Engineer","hourly_wage_mean":51.31,"hourly_wage_median":48.83,"annual_wage_median":101560.0,"salary_id":7},{"state":"CA","job_title":"Data Scientist","hourly_wage_mean":55.45,"hourly_wage_median":50.95,"annual_wage_median":105980.0,"salary_id":8},{"state":"CO","job_title":"Data Engineer","hourly_wage_mean":45.12,"hourly_wage_median":45.51,"annual_wage_median":94660.0,"salary_id":9},{"state":"CO","job_title":"Data Scientist","hourly_wage_mean":46.14,"hourly_wage_median":43.12,"annual_wage_median":89700.0,"salary_id":10},{"state":"CT","job_title":"Data Engineer","hourly_wage_mean":50.59,"hourly_wage_median":50.97,"annual_wage_median":106030.0,"salary_id":11},{"state":"CT","job_title":"Data Scientist","hourly_wage_mean":46.16,"hourly_wage_median":45.81,"annual_wage_median":95280.0,"salary_id":12},{"state":"DE","job_title":"Data Engineer","hourly_wage_mean":44.45,"hourly_wage_median":42.53,"annual_wage_median":88460.0,"salary_id":13},{"state":"DC","job_title":"Data Engineer","hourly_wage_mean":49.85,"hourly_wage_median":48.67,"annual_wage_median":101230.0,"salary_id":14},{"state":"FL","job_title":"Data Engineer","hourly_wage_mean":43.43,"hourly_wage_median":43.38,"annual_wage_median":90230.0,"salary_id":15},{"state":"FL","job_title":"Data Scientist","hourly_wage_mean":38.93,"hourly_wage_median":30.89,"annual_wage_median":64250.0,"salary_id":16},{"state":"GA","job_title":"Data Engineer","hourly_wage_mean":45.25,"hourly_wage_median":45.81,"annual_wage_median":95290.0,"salary_id":17},{"state":"GA","job_title":"Data Scientist","hourly_wage_mean":39.19,"hourly_wage_median":35.29,"annual_wage_median":73410.0,"salary_id":18},{"state":"HI","job_title":"Data Engineer","hourly_wage_mean":45.19,"hourly_wage_median":45.22,"annual_wage_median":94050.0,"salary_id":19},{"state":"ID","job_title":"Data Engineer","hourly_wage_mean":34.02,"hourly_wage_median":30.93,"annual_wage_median":64330.0,"salary_id":20},{"state":"IL","job_title":"Data Engineer","hourly_wage_mean":47.06,"hourly_wage_median":47.93,"annual_wage_median":99690.0,"salary_id":21},{"state":"IL","job_title":"Data Scientist","hourly_wage_mean":48.68,"hourly_wage_median":46.68,"annual_wage_median":97090.0,"salary_id":22},{"state":"IN","job_title":"Data Engineer","hourly_wage_mean":35.83,"hourly_wage_median":33.73,"annual_wage_median":70160.0,"salary_id":23},{"state":"IN","job_title":"Data Scientist","hourly_wage_mean":38.7,"hourly_wage_median":37.11,"annual_wage_median":77180.0,"salary_id":24},{"state":"IA","job_title":"Data Engineer","hourly_wage_mean":44.89,"hourly_wage_median":45.78,"annual_wage_median":95210.0,"salary_id":25},{"state":"KS","job_title":"Data Engineer","hourly_wage_mean":43.18,"hourly_wage_median":41.73,"annual_wage_median":86790.0,"salary_id":26},{"state":"KS","job_title":"Data Scientist","hourly_wage_mean":33.43,"hourly_wage_median":31.52,"annual_wage_median":65560.0,"salary_id":27},{"state":"KY","job_title":"Data Engineer","hourly_wage_mean":42.0,"hourly_wage_median":40.74,"annual_wage_median":84740.0,"salary_id":28},{"state":"KY","job_title":"Data Scientist","hourly_wage_mean":35.61,"hourly_wage_median":29.62,"annual_wa ...

# %%
state_boundary = pd.read_sql('SELECT * FROM state_boundary', connection)

# %%
display(state_boundary)
# Out:
#    state                                           geometry
# 0     AL  POLYGON ((-85.07006709656061 31.9807030853166,...
# 1     AK  MULTIPOLYGON (((-161.333785127379 58.733248100...
# 2     AZ  POLYGON ((-114.520627666533 33.0277074291687, ...
# 3     AR  POLYGON ((-94.4616914446557 34.1967651981701, ...
# 4     CA  MULTIPOLYGON (((-121.665219944683 38.169285281...
# 5     CO  POLYGON ((-102.044455912804 37.6414742305057, ...
# 6     CT  POLYGON ((-73.5303920868235 41.5227455387049, ...
# 7     DE  POLYGON ((-75.7070735459597 38.5575913689919, ...
# 8     DC  POLYGON ((-77.0079307376576 38.9666671467883, ...
# 9     FL  MULTIPOLYGON (((-80.78566240012439 28.78519401...
# 10    GA  MULTIPOLYGON (((-85.1301648591002 31.778853670...
# 11    HI  MULTIPOLYGON (((-160.073803550368 22.004177303...
# 12    ID  POLYGON ((-117.026295236851 43.6790312294755, ...
# 13    IL  POLYGON ((-88.0715914836514 37.5110386009516, ...
# 14    IN  POLYGON ((-86.3416058957487 38.1772881245416, ...
# 15    IA  POLYGON ((-91.12013243987199 40.7054431031224,...
# 16    KS  POLYGON ((-95.0719311142617 37.0014780616281, ...
# 17    KY  MULTIPOLYGON (((-86.5106681712262 36.655074189...
# 18    LA  MULTIPOLYGON (((-93.70752399064079 30.23957880...
# 19    ME  MULTIPOLYGON (((-69.77727625338269 44.07414830...
# 20    MD  MULTIPOLYGON (((-75.71071272792589 38.64966584...
# 21    MA  MULTIPOLYGON (((-71.3193277686743 41.772195872...
# 22    MI  MULTIPOLYGON (((-88.4975275077301 48.173795293...
# 23    MN  POLYGON ((-91.7303661520137 43.4995717796755, ...
# 24    MS  POLYGON ((-88.45080311338261 31.4356176669309,...
# 25    MO  POLYGON ((-89.1050338408038 36.9539220570356, ...
# 26    MT  POLYGON ((-111.475425118025 44.7021622515988, ...
# 27    NE  POLYGON ((-101.407393354875 40.0010036934654, ...
# 28    NV  POLYGON ((-119.152450403186 38.4118009703454, ...
# 29    NH  POLYGON ((-72.2799169136774 42.7204670525699, ...
# 30    NJ  POLYGON ((-75.4892806610995 39.7148582277939, ...
# 31    NM  POLYGON ((-109.04949530948 32.4420444765386, -...
# 32    NY  MULTIPOLYGON (((-79.7632349804647 42.267327069...
# 33    NC  MULTIPOLYGON (((-83.9884542352999 34.989151807...
# 34    ND  POLYGON ((-98.73043691966031 45.9382710249208,...
# 35    OH  POLYGON ((-83.2727548550436 38.6092569362287, ...
# 36    OK  POLYGON ((-94.4393221496037 34.9291508667444, ...
# 37    OR  POLYGON ((-121.441508914554 41.9943345459876, ...
# 38    PA  POLYGON ((-77.4757933767757 39.7196232151451, ...
# 39    RI  MULTIPOLYGON (((-71.790194213215 41.6013068825...
# 40    SC  MULTIPOLYGON (((-81.7595935200717 33.195380993...
# 41    SD  POLYGON ((-102.788384557444 42.9953035928248, ...
# 42    TN  POLYGON ((-83.9546078589193 35.4555442998173, ...
# 43    TX  MULTIPOLYGON (((-105.998886802242 31.393940073...
# 44    UT  POLYGON ((-114.047273022174 38.1376524395382, ...
# 45    VT  POLYGON ((-73.25805980563879 42.7460586624827,...
# 46    VA  MULTIPOLYGON (((-79.1440627921428 36.546198364...
# 47    WA  MULTIPOLYGON (((-122.402015587527 48.225216553...
# 48    WV  POLYGON ((-79.23166290478569 38.4804961830735,...
# 49    WI  MULTIPOLYGON (((-87.7485548591816 44.961616773...
# 50    WY  POLYGON ((-104.053615178751 41.6982182532382, ...

# %%
state_boundary_json = state_boundary.to_json(orient = "records")

# %%
display(state_boundary_json)
# Out:
# '[{"state":"AL","geometry":"POLYGON ((-85.07006709656061 31.9807030853166, -85.1151502353308 31.9074247692196, -85.13556693252841 31.854884438973, -85.1315611333751 31.7838145808812, -85.1301648591002 31.7788536706529, -85.11528694619081 31.7315659591805, -85.1186744123295 31.7085715965888, -85.1112049432955 31.6842420884887, -85.0592853290494 31.6212651610454, -85.0427213500685 31.5543898242226, -85.042698452683 31.5196599299495, -85.06631202895819 31.4760895727389, -85.0614062900318 31.4406634321759, -85.0879419767593 31.3672342109121, -85.08256321514889 31.3323345029977, -85.0812280696406 31.3030803474969, -85.10336134548891 31.2714361608328, -85.09360327760081 31.2270744969198, -85.10295711856909 31.1969220593752, -85.0933668957689 31.1722112735449, -85.0686624818354 31.162364102709, -85.0380682076385 31.1267131844188, -85.0169956713016 31.0801028107621, -85.0016071777796 31.0012533846564, -85.4850101998634 31.0010018242409, -85.4865971130033 31.000997990742, -86.03182178064699 30.9933276256432, -86.1814761907909 30.9952251039996, -86.38391974598279 30.9915383141211, -86.70185248107541 30.9980924057782, -86.7793616848769 30.9981918177299, -87.16311761675141 31.0031572349096, -87.59858024827 31.0026307504568, -87.58986722326949 30.954361041613, -87.62571157784291 30.8769019841216, -87.61591517496571 30.8482964151945, -87.541900153624 30.7856953260574, -87.5266028870155 30.7484916852932, -87.4601404801909 30.7058026184015, -87.4188942594055 30.6928101653114, -87.3986449410594 30.6680153533291, -87.3932809436002 30.6200982745817, -87.4220673604289 30.5564935857885, -87.4453529653304 30.531389710907, -87.4188166569545 30.4817007785988, -87.4052508367559 30.4403600672454, -87.46644036942649 30.3597214332258, -87.5875683672155 30.3192543451934, -87.5934048175144 30.278415355962, -87.7953306431362 30.2339316417321, -88.0025605289436 30.233604292007, -87.7799416833778 30.2726382730924, -87.75750297091309 30.2994222565809, -87.9034657734028 30.4212960771256, -87.9133851590697 30.6211843980725, -88.0197888429262 30.7441900332707, -88.1356811618617 30.3371585464784, -88.32032666224541 30.4042935769509, -88.4014151625435 30.3935518021581, -88.4172426434957 30.7364571406963, -88.4291990157972 31.0006950925234, -88.4345631168644 31.1208794797341, -88.45080311338261 31.4356176669309, -88.4650968321393 31.7022450282728, -88.4729519304428 31.8888767991366, -88.4377242511548 32.2277556169058, -88.42579201953571 32.3092243070492, -88.39383250168351 32.5804702057229, -88.3480414607145 32.9247582458777, -88.3394663380669 32.9874971855638, -88.30482958745669 33.2888943302892, -88.2745867000593 33.5388014716674, -88.2481955984059 33.742726415171, -88.2026446691596 34.0591222798257, -88.1993492587991 34.0904480788635, -88.1676133271811 34.32414749764, -88.1512564089459 34.4652732533597, -88.1364016006381 34.5804973001865, -88.09046866840509 34.8956296643194, -88.1088865067411 34.8999364449418, -88.14310493973279 34.9303124687206, -88.1939936017903 35.0044536328983, -88.1949623891317 35.0135438431099, -87.986078244933 35.0160336488533, -87.6078130750022 35.0105466168004, -87.2227639070873 35.0073462150482, -87.2075884835795 35.0079604037398, -86.8334221010528 34.998246058461, -86.7823722248246 34.9970753389738, -86.3130526489014 34.9952731282459, -86.30350039846211 34.9954638707191, -85.86956754022791 34.9923845350071, -85.6089602227006 34.9901641620728, -85.5830580475713 34.8623226715974, -85.5346926048626 34.622488411255, -85.52583411411931 34.5846856049707, -85.5118559337669 34.5230148645778, -85.4602859449828 34.2901615093732, -85.41656722100321 34.0869203791902, -85.3957378010235 33.9598292702259, -85.3840109206167 33.9054098002528, -85.335286838543 33.6549230752814, -85.30498007676491 33.4905940312789, -85.2938250093455 33.42587571105, -85.23384629248849 33.1292372853871, -85.23350288351109 33.1201394081776, -85.1807197477316 32.8718130152587, -85.16230133955111 32.8074457710051, -85.1280897964966 32.7770703688748, -85.1333007130193 32.75631 ...
